# %% [markdown]
# Assignment 1 (Submitted By : Samarthya Dev Gupta 102315018)

# %%
import numpy as np

# %% [markdown]
# 1. Reverse the NumPy array: arr = np.array([1, 2, 3, 6, 4, 5]) )

# %%
arr = np.array([1,2,3,6,4,5])
print(arr[::-1])
# Out:
# [5 4 6 3 2 1]

# %% [markdown]
# 2.Compare the following numpy arrays: arr1 = np.array([[1, 2], [3, 4]])
# arr2 = np.array([[1, 2], [3, 4]])

# %%
arr1 = np.array([[1,2],[3,4]])
arr2 = np.array([[1,2],[3,4]])

if np.array_equal(arr1, arr2):
    print("Equal")
else:
    print("Not Equal")
# Out:
# Equal

# %% [markdown]
# 3.Find the most frequent value and their indice(s) in the following arrays:
# i.
# x = np.array([1,2,3,4,5,1,2,1,1,1])
# ii.
# 4.
# y = np.array([1, 1, 1, 2, 3, 4, 2, 4, 3, 3, ])

# %%
x = np.array([1,2,3,4,5,1,2,1,1,1])
y = np.array([1, 1, 1, 2, 3, 4, 2, 4, 3, 3, ])

def function(arr, name):
    vals, counts = np.unique(arr, return_counts=True)
    max_count = counts.max()

    modes = vals[counts == max_count]

    print(f"Results for array {name}:")
    for mode in modes:
        indices = np.where(arr == mode)[0]
        print(f"Value: {mode}, Indices: {indices}")
    print("")

function(x, "x")
function(y, "y")
# Out:
# Results for array x:
# Value: 1, Indices: [0 5 7 8 9]
#
# Results for array y:
# Value: 1, Indices: [0 1 2]
# Value: 3, Indices: [4 8 9]

# %% [markdown]
# 4. For the array gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]'),
# find
#
# i. Sum of all elements
#
# ii. Sum of all element’s row-wise
#
# iii.Sum of all element’s column-wise

# %%
gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]')

# i. Sum of all elements
print(f" Sum of all elements: {gfg.sum()}")

# ii. Sum of all Elements row-wise
print(f" Row Wise Sum: {gfg.sum(axis=1)}")

# iii. Sum of all Elements column-wise
print(f" Column-wise Sum: {gfg.sum(axis=0)}")
# Out:
#  Sum of all elements: 45
#  Row Wise Sum: [[14]
#  [16]
#  [15]]
#  Column-wise Sum: [[20  9 16]]

# %% [markdown]
# End of Assignment
